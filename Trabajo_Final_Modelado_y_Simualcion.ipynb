# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaG0205/ModeladoySimulacion/blob/main/Trabajo_Final_Modelado_y_Simualcion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ejercicios para el documento sobre BIFURCACIONES**
# **Articulo: Análisis de bifurcación para un sistema de transmisión eléctrico con sobrecarga**
# ##Maria Alejandra Giraldo Duque. Cod. 817021
#
# Implementación y desarrollo basado en Canizares, C. A. (1995). "On bifurcations, voltage collapse and load modeling". IEEE Transactions on Power Systems, 10(1), 512–522.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import sympy as sp
from scipy.integrate import solve_ivp
from ipywidgets import interact
import time
from tqdm import tqdm

# %% [markdown]
# ###**Raices del sistema.**

# %%
#Se definene los puntos cercanos a puntos de equilibrio 
y = np.linspace(-6,3, 150)
x= np.linspace(-6,3, 150)

#Parametros donde la potencia es variable 
@interact(p=(0, 3, 0.1))
def p(p=2):
  v=1
  m=d=0.1
  reactancia=0.5
  g = 0*x
  h = 1/d*(p-v/reactancia*np.sin(y))

  
  plt.figure(figsize=(10,6))
  plt.plot(x,g,x, h)
  plt.grid()
  plt.legend([r'$g(x)$', r'$h(x)$'])
  plt.xticks([-3*np.pi/2,-np.pi, -np.pi/2, 0, np.pi/2],[r'$-3\pi/2$',r'$-\pi$', r'$-\pi/2$', r'$0$', r'$\pi/2$'])
  plt.xlabel(r'$x$')
  plt.ylabel(r'$g(x)$, $h(x)$')
# Out:
# interactive(children=(FloatSlider(value=2.0, description='p', max=3.0), Output()), _dom_classes=('widget-inter…

# %% [markdown]
# ###**Respuesta del sistema dinámico en el tiempo cuando P=1.99 y P=2.**

# %%
#aqui y[1]= omega, y[0]=delta
@interact(p=(0, 3, 0.01))
def p(p=2):
  v=1
  reac=0.5
  d=0.1
  m=0.1
  def powersys (t,y,m,p,reac,d,v):
    return (y[1],1/m*(p-(v/reac)*np.sin(y[0])-d*y[1]))

  Ti,Tf=0,100
  t= np.linspace(Ti,Tf,100)
  y0=[np.pi/2-0.1,0.01]

  sol=solve_ivp(powersys,[Ti,Tf],y0,args=(m,p,reac,d,v),t_eval=t)

  plt.figure(figsize=(15,6))
  plt.subplot(121)
  plt.plot(t,sol.y[0], color="blue")
  plt.grid()
  plt.legend([r'$d(t)$'])
  plt.xlabel(r'$t$')
  plt.ylabel(r'$d$')

 
  plt.subplot(122)
  plt.plot(t,sol.y[1],color="red")
  plt.grid()
  plt.legend([r'$w(t)$'])
  plt.xlabel(r'$t$')
  plt.ylabel(r'$w$')
# Out:
# interactive(children=(FloatSlider(value=2.0, description='p', max=3.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# ###**Diagrama de bifurcación del sistema cuando P=2.**

# %%
def power (t,y,m,p):
  return (y[1],1/m*(p-1/0.5*np.sin(y[0])-0.1*y[1]))

Ti,Tf=0,50
t= np.linspace(Ti,Tf,100)

tic=time.clock()

plt.figure(figsize=(6,6))
x=np.linspace(0,2,300)
y=np.arcsin(x*0.5/1)*180/np.pi
plt.plot(x,y,'g')

for p in np.arange(0,3,0.2):
  for y1 in np.arange(-1,2,0.1):
    for x1 in np.arange (0,1,0.1):
      sol=solve_ivp(power,[Ti,Tf],[y1,x1],args=(0.1,p),t_eval=t)
      plt.plot(p,sol.y[0][-1]*180/np.pi, '*r') 
      plt.xlabel(r'$p$')
      plt.ylabel(r'$d$')

plt.ylim((0,180))
toc=time.clock()
print("time=",toc-tic)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# time= 174.70606

# %% [markdown]
# ###**Código para obtener los puntos de equilibrio para cualquier valor de P**

# %%
#Se hallan los puntos de equilibrio del sistema
v=1
m=d=0.1
reactancia=0.5
#Ingresar valor de P=<2
p=2
r, c = sp.symbols('r, c', real=True)
R = c
C = 1/m*(p-v/reactancia*sp.sin(r)-d*c)

#Usando sympy se igualan las ecuacuaciones a cero
REqual = sp.Eq(R, 0)
CEqual = sp.Eq(C, 0)

fp = sp.solve( (REqual, CEqual), r, c )
print(fp)
# Out:
# [(1.57079632679490, 0.0)]

# %% [markdown]
# ###**Diagrama de fase cuando P=2, en el punto de bifurcación.**

# %%
fp=[(1.57,0),(-4.75,0)]
v=1
reactancia=0.5
d=0.1
m=0.1
p=1.99
def Sys(X, t=0):
    # aqui X[0] = x and X[1] = y    
    return np.array([X[1] , 1/m*(p-v/reactancia*np.sin(X[0])-d*X[1])])


fig2 = plt.figure(figsize=(12,8))
ax4 = fig2.add_subplot(1,1,1)

#Graficas isoclinas
ax4.plot([-5,3],[0,0], 'r-', lw=2, label='x´')
#ax4.plot([1,1],[-1,3], 'b-', lw=2, label='y´')

#Se grafican los puntos de equilibrio
for point in fp:
    ax4.plot(point[0],point[1],"red", marker = "o", markersize = 10.0)
ax4.set_title("Plano de fase")
ax4.legend(loc='best')

x = np.linspace(-5, 3, 60)
y = np.linspace(-5, 3, 60)


X1 , Y1  = np.meshgrid(x, y)                    
DX1, DY1 = Sys([X1, Y1])                       
M = (np.hypot(DX1, DY1))                        
M[ M == 0] = 1.                                  
DX1 /= M                                        
DY1 /= M

ax4.streamplot (X1, Y1, DX1, DY1, density = 3)
ax4.legend()
ax4.grid()

# %% [markdown]
# ###**Diagrama de fase cuando P<2**
# Aquí se puede ver el punto de silla inestable y el foco estable.

# %%
fp=[(0.25,0),(2.88,0)]
v=1
reactancia=0.5
d=0.1
m=0.1
p=0.5
def Sys(X, t=0):
    # aqui X[0] = x and X[1] = y    
    return np.array([X[1] , 1/m*(p-v/reactancia*np.sin(X[0])-d*X[1])])


fig2 = plt.figure(figsize=(12,8))
ax4 = fig2.add_subplot(1,1,1)

#Graficas isoclinas
ax4.plot([-5,3],[0,0], 'r-', lw=2, label='x´')
#ax4.plot([1,1],[-1,3], 'b-', lw=2, label='y´')

#Se grafican los puntos de equilibrio
for point in fp:
    ax4.plot(point[0],point[1],"red", marker = "o", markersize = 10.0)
ax4.set_title("Plano de fase")
ax4.legend(loc='best')

x = np.linspace(-5, 3, 60)
y = np.linspace(-5, 3, 60)


X1 , Y1  = np.meshgrid(x, y)                    
DX1, DY1 = Sys([X1, Y1])                       
M = (np.hypot(DX1, DY1))                        
M[ M == 0] = 1.                                  
DX1 /= M                                        
DY1 /= M

ax4.streamplot (X1, Y1, DX1, DY1, density = 3)
ax4.legend()
ax4.grid()

# %% [markdown]
# ###**Diagrama de fase cuando P=1.99**
# Aquí se puede ver la coexistencia del ciclo limite y los puntos de equilibrio del sistema.

# %%
fp=[(1.470,0),(1.8,0)]
v=1
reactancia=0.5
d=0.1
m=0.1
p=1.99
def Sys(X, t=0):
    # aqui X[0] = x and X[1] = y    
    return np.array([X[1] , 1/m*(p-v/reactancia*np.sin(X[0])-d*X[1])])


fig2 = plt.figure(figsize=(12,8))
ax4 = fig2.add_subplot(1,1,1)

#Graficas isoclinas
ax4.plot([-5,3],[0,0], 'r-', lw=2, label='x´')
#ax4.plot([1,1],[-1,3], 'b-', lw=2, label='y´')

#Se grafican los puntos de equilibrio
for point in fp:
    ax4.plot(point[0],point[1],"red", marker = "o", markersize = 10.0)
ax4.set_title("Plano de fase")
ax4.legend(loc='best')

x = np.linspace(-5, 3, 60)
y = np.linspace(-5, 3, 60)


X1 , Y1  = np.meshgrid(x, y)                    
DX1, DY1 = Sys([X1, Y1])                       
M = (np.hypot(DX1, DY1))                        
M[ M == 0] = 1.                                  
DX1 /= M                                        
DY1 /= M

ax4.streamplot (X1, Y1, DX1, DY1, density = 3)
ax4.legend()
ax4.grid()

# %% [markdown]
# ###**Diagrama de fase cuando P>2.**
# Aquí se puede ver el ciclo limite que presenta el sistema

# %%
fp=[(1.57,0),(-4.71,0)]
v=1
reactancia=0.5
d=0.1
m=0.1
p=2.2
def Sys(X, t=0):
    # aqui X[0] = x and X[1] = y    
    return np.array([X[1] , 1/m*(p-v/reactancia*np.sin(X[0])-d*X[1])])


fig2 = plt.figure(figsize=(12,8))
ax4 = fig2.add_subplot(1,1,1)

#Graficas isoclinas
#ax4.plot([-5,3],[0,0], 'r-', lw=2, label='x´')
#ax4.plot([1,1],[-1,3], 'b-', lw=2, label='y´')

#Se grafican los puntos de equilibrio
#for point in fp:
 #   ax4.plot(point[0],point[1],"red", marker = "o", markersize = 10.0)
ax4.set_title("Plano de fase")
ax4.legend(loc='best')

x = np.linspace(-10, 10, 60)
y = np.linspace(-10, 10, 60)


X1 , Y1  = np.meshgrid(x, y)                    
DX1, DY1 = Sys([X1, Y1])                       
M = (np.hypot(DX1, DY1))                        
M[ M == 0] = 1.                                  
DX1 /= M                                        
DY1 /= M

ax4.streamplot (X1, Y1, DX1, DY1, density = 3)
ax4.legend()
ax4.grid()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
